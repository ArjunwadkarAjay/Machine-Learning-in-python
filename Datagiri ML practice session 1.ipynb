# %%
# !pip install seaborn
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x03DA4490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/seaborn/
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x03DA4870>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/seaborn/
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x03DA4A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/seaborn/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#       car_company           model_ID  mileage  engine_power registration_date  \
# 0  Edureka_motors   318 Gran Turismo   140245           105        01-10-2014
# 1  Edureka_motors  218 Active Tourer    91512           100        01-06-2015
# 2  Edureka_motors                318   113744           100        01-06-2012
# 3  Edureka_motors   320 Gran Turismo   195063           135        01-05-2014
# 4  Edureka_motors                518   148943           100        01-11-2013
#
#      fuel car_paint_color   car_type  feature1  feature2  feature3  feature4  \
# 0  diesel           white  hatchback     False      True     False     False
# 1  petrol           white        van     False      True      True     False
# 2  diesel            grey      sedan      True      True     False     False
# 3  diesel           black  hatchback     False      True      True     False
# 4  diesel           brown     estate      True      True      True     False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 18 columns):
# car_company          3390 non-null object
# model_ID             3390 non-null object
# mileage              3390 non-null int64
# engine_power         3390 non-null int64
# registration_date    3390 non-null object
# fuel                 3390 non-null object
# car_paint_color      3390 non-null object
# car_type             3390 non-null object
# feature1             3390 non-null bool
# feature2             3390 non-null bool
# feature3             3390 non-null bool
# feature4             3390 non-null bool
# feature5             3390 non-null bool
# feature6             3390 non-null bool
# feature7             3390 non-null bool
# feature8             3390 non-null bool
# sold_date            3390 non-null object
# car_price            3390 non-null int64
# dtypes: bool(8), int64(3), object(7)
# memory usage: 198.7+ KB

# %%
df.describe()
# Out:
#             mileage  engine_power      car_price
# count  3.390000e+03   3390.000000    3390.000000
# mean   1.416107e+05    128.917109   15899.203540
# std    6.142411e+04     39.384193    9444.167874
# min   -6.400000e+01      0.000000     100.000000
# 25%    1.032490e+05    100.000000   10900.000000
# 50%    1.416600e+05    120.000000   14200.000000
# 75%    1.753025e+05    135.000000   18600.000000
# max    1.000376e+06    423.000000  178500.000000

# %%
df.columns
# Out:
# Index(['car_company', 'model_ID', 'mileage', 'engine_power',
#        'registration_date', 'fuel', 'car_paint_color', 'car_type', 'feature1',
#        'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7',
#        'feature8', 'sold_date', 'car_price'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
sn.pairplot(df)
# Out:
# c:\users\ajay arjunwadkar\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py:778: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   a, weights = _ravel_and_check_weights(a, weights)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ajay arjunwadkar\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-37b28187c14a> in <module>
# ----> 1 sn.pairplot(df)
#
# ...
