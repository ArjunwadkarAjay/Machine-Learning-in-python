# %%
import pandas as pd

# %%
df=pd.read_csv("world bank data.csv")
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
data = pd.read_csv("world bank data.csv", error_bad_lines=False)
data
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', 'Unnamed: 63'],
#       dtype='object')

# %%
data.loc[data['Country Name']=='India',:]
# Out:
#     Country Name Country Code     Indicator Name  Indicator Code  \
# 107        India          IND  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 107  3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10  5.648029e+10
#
#              1965  ...          2010          2011          2012  \
# 107  5.955486e+10  ...  1.675615e+12  1.823050e+12  1.827638e+12
#
#              2013          2014          2015          2016          2017  \
# 107  1.856722e+12  2.039127e+12  2.103588e+12  2.290432e+12  2.652551e+12
#
#              2018  Unnamed: 63
# 107  2.726323e+12          NaN
#
# [1 rows x 64 columns]

# %%
data=data.drop(columns=['Unnamed: 63'])

# %%
data
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
data=data.loc[data['Country Name']=='India',:]
data
# Out:
#     Country Name Country Code     Indicator Name  Indicator Code  \
# 107        India          IND  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 107  3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10  5.648029e+10
#
#              1965  ...          2009          2010          2011  \
# 107  5.955486e+10  ...  1.341887e+12  1.675615e+12  1.823050e+12
#
#              2012          2013          2014          2015          2016  \
# 107  1.827638e+12  1.856722e+12  2.039127e+12  2.103588e+12  2.290432e+12
#
#              2017          2018
# 107  2.652551e+12  2.726323e+12
#
# [1 rows x 63 columns]

# %%
years=data.columns[4:]
f=data.iloc[:,4:]
# df.columns
years
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
col = list(data.columns[4:])
val = data[col].values.tolist()[0]
# fin = list(zip(col,val))
# fin
df1 = pd.DataFrame({'years':col,'gdp':val})
df1
df1.to_csv("GDPfinal.csv",index=False)

# %%
f=pd.read_csv("GDPfinal.csv")

# %%
f
# Out:
#     years           gdp
# 0    1960  3.702988e+10
# 1    1961  3.923244e+10
# 2    1962  4.216148e+10
# 3    1963  4.842192e+10
# 4    1964  5.648029e+10
# 5    1965  5.955486e+10
# 6    1966  4.586546e+10
# 7    1967  5.013494e+10
# 8    1968  5.308546e+10
# 9    1969  5.844800e+10
# 10   1970  6.242248e+10
# 11   1971  6.735099e+10
# 12   1972  7.146320e+10
# 13   1973  8.551527e+10
# 14   1974  9.952590e+10
# 15   1975  9.847280e+10
# 16   1976  1.027172e+11
# 17   1977  1.214873e+11
# 18   1978  1.373003e+11
# 19   1979  1.529917e+11
# 20   1980  1.863253e+11
# 21   1981  1.934906e+11
# 22   1982  2.007152e+11
# 23   1983  2.182623e+11
# 24   1984  2.121582e+11
# 25   1985  2.325119e+11
# 26   1986  2.489860e+11
# 27   1987  2.790336e+11
# 28   1988  2.965890e+11
# 29   1989  2.960424e+11
# 30   1990  3.209790e+11
# 31   1991  2.701053e+11
# 32   1992  2.882084e+11
# 33   1993  2.792960e+11
# 34   1994  3.272756e+11
# 35   1995  3.602820e+11
# 36   1996  3.928971e+11
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("GDPfinal.csv")

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['years']],df.gdp)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x=reg.predict([[2019]])
x
# Out:
# array([1.65083699e+12])

# %%
d=pd.read_csv("years.csv")
d
# Out:
#     years
# 0    2019
# 1    2020
# 2    2021
# 3    2022
# 4    2023
# 5    2024
# 6    2025
# 7    2026
# 8    2027
# 9    2028
# 10   2029

# %%
p=reg.predict(d)

# %%
d['GDP']=p

# %%
d
# Out:
#     years           GDP
# 0    2019  1.650837e+12
# 1    2020  1.686267e+12
# 2    2021  1.721698e+12
# 3    2022  1.757128e+12
# 4    2023  1.792558e+12
# 5    2024  1.827989e+12
# 6    2025  1.863419e+12
# 7    2026  1.898849e+12
# 8    2027  1.934280e+12
# 9    2028  1.969710e+12
# 10   2029  2.005140e+12

# %%
d.to_csv("gdpResults.csv",index=False)
